# %%
import os
import random

import numpy as np
import pandas as pd
from PIL import Image
from time import time
from tqdm.auto import tqdm

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [5, 5]
matplotlib.rcParams['figure.dpi'] = 200

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision

from data_helper import CustomUnlabeledDataset, LabeledDataset
from helper import collate_fn, draw_box

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0);

# %%
# All the images are saved in image_folder
# All the labels are saved in the annotation_csv file
image_folder = '../data'
annotation_csv = '../data/annotation.csv'

# %%
# You shouldn't change the unlabeled_scene_index
# The first 106 scenes are unlabeled
unlabeled_scene_index = np.arange(106)
# The scenes from 106 - 133 are labeled
# You should devide the labeled_scene_index into two subsets (training and validation)
labeled_scene_index = np.arange(106, 134)

# %%
transform = torchvision.transforms.ToTensor()

unlabeled_trainset = CustomUnlabeledDataset(
    image_folder=image_folder,
    scene_index=unlabeled_scene_index,
)
trainloader = torch.utils.data.DataLoader(
    unlabeled_trainset,
    batch_size=8,
    shuffle=True,
    num_workers=2
)

# %%
# [batch_size, 9, 3, H, W]
images, labels, original = iter(trainloader).next()
print(images.shape)
# Out:
# torch.Size([8, 9, 3, 75, 75])

# %%
sample = 1
plt.imshow(torchvision.utils.make_grid(images[sample], nrow=3).numpy().transpose(1, 2, 0))
plt.axis('off');
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# all_perm = np.load("permutations_1000.npy")
# # from range [1,9] to [0,8]
# if all_perm.mdin() == 1:
#     all_perm = all_perm - 1
#     
# temp = [original[np.arange(9)[t]] for t in range(9)]
# temp = torch.stack(temp, 0)
# 
# plt.imshow(torchvision.utils.make_grid(temp[:, sample, :, :, :], nrow=3).numpy().transpose(1, 2, 0))
# plt.axis('off');

# %%
from JigsawNetwork import Network
from Utils.TrainingUtils import compute_accuracy, adjust_learning_rate

# Network initialize
net = Network()
net.cuda()
# Out:
# Network(
#   (conv): Sequential(
#     (conv1_s1): Conv2d(3, 96, kernel_size=(11, 11), stride=(2, 2))
#     (relu1_s1): ReLU(inplace=True)
#     (pool1_s1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (lrn1_s1): LRN(
#       (average): AvgPool3d(kernel_size=(5, 1, 1), stride=1, padding=(2, 0, 0))
#     )
#     (conv2_s1): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2)
#     (relu2_s1): ReLU(inplace=True)
#     (pool2_s1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (lrn2_s1): LRN(
#       (average): AvgPool3d(kernel_size=(5, 1, 1), stride=1, padding=(2, 0, 0))
#     )
#     (conv3_s1): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu3_s1): ReLU(inplace=True)
#     (conv4_s1): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2)
#     (relu4_s1): ReLU(inplace=True)
#     (conv5_s1): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2)
#     (relu5_s1): ReLU(inplace=True)
#     (pool5_s1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc6): Sequential(
#     (fc6_s1): Linear(in_features=2304, out_features=1024, bias=True)
#     (relu6_s1): ReLU(inplace=True)
#     (drop6_s1): Dropout(p=0.5, inplace=False)
#   )
#   (fc7): Sequential(
#     (fc7): Linear(in_features=9216, out_features=4096, bias=True)
#     (relu7): ReLU(inplace=True)
#     (drop7): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (fc8): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)

# %%
############## TRAINING ###############
batch_time, net_time = [], []
steps = 0
for epoch in tqdm(range(10)):
    end = time()
    for i, (images, labels, original) in enumerate(trainloader):
        lr = adjust_learning_rate(optimizer, epoch, init_lr=0.001, step=5, decay=0.1)
        batch_time.append(time() - end)
        if len(batch_time) > 100:
            del batch_time[0]

        images = images.cuda()
        labels = labels.cuda()

        # Forward + Backward + Optimize
        optimizer.zero_grad()
        t = time()
        outputs = net(images)
        net_time.append(time() - t)
        if len(net_time) > 100:
            del net_time[0]

        prec1, prec5 = compute_accuracy(
            outputs.cpu().data, labels.cpu().data, topk=(1, 5)
        )
        acc = prec1.item()

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        loss = float(loss.cpu().data.numpy())

        if steps % 20 == 0:
            print(
                (
                    "[%2d/%2d] %5d) [batch load % 2.3fsec, net %1.2fsec], LR %.5f, Loss: % 1.3f, Accuracy % 2.2f%%"
                    % (
                        epoch + 1,
                        10,
                        steps,
                        np.mean(batch_time),
                        np.mean(net_time),
                        lr,
                        loss,
                        acc,
                    )
                )
            )

        steps += 1
        end = time()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# [ 1/10]     0) [batch load  4.562sec, net 1.45sec], LR 0.00100, Loss:  6.907, Accuracy  0.00%
# [ 1/10]    20) [batch load  0.224sec, net 0.10sec], LR 0.00100, Loss:  6.909, Accuracy  0.00%
# [ 1/10]    40) [batch load  0.115sec, net 0.07sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]    60) [batch load  0.078sec, net 0.06sec], LR 0.00100, Loss:  6.912, Accuracy  0.00%
# [ 1/10]    80) [batch load  0.059sec, net 0.05sec], LR 0.00100, Loss:  6.909, Accuracy  0.00%
# [ 1/10]   100) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.916, Accuracy  0.00%
# [ 1/10]   120) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]   140) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.909, Accuracy  0.00%
# [ 1/10]   160) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.903, Accuracy  0.00%
# [ 1/10]   180) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.902, Accuracy  0.00%
# [ 1/10]   200) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]   220) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.907, Accuracy  0.00%
# [ 1/10]   240) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]   260) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]   280) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.900, Accuracy  0.00%
# [ 1/10]   300) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.914, Accuracy  0.00%
# [ 1/10]   320) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]   340) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]   360) [batch load  0.001sec, net 0.04sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]   380) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]   400) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]   420) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]   440) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]   460) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.907, Accuracy  0.00%
# [ 1/10]   480) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]   500) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.918, Accuracy  0.00%
# [ 1/10]   520) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]   540) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.907, Accuracy  0.00%
# [ 1/10]   560) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]   580) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]   600) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]   620) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.910, Accuracy  0.00%
# [ 1/10]   640) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]   660) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.900, Accuracy  0.00%
# [ 1/10]   680) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.903, Accuracy  0.00%
# [ 1/10]   700) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.909, Accuracy  0.00%
# [ 1/10]   720) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.900, Accuracy  0.00%
# [ 1/10]   740) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.916, Accuracy  0.00%
# [ 1/10]   760) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.900, Accuracy  0.00%
# [ 1/10]   780) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]   800) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.916, Accuracy  0.00%
# [ 1/10]   820) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.912, Accuracy  0.00%
# [ 1/10]   840) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]   860) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]   880) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]   900) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]   920) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]   940) [batch load  0.003sec, net 0.05sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]   960) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]   980) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]  1000) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.903, Accuracy  0.00%
# [ 1/10]  1020) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.900, Accuracy  0.00%
# [ 1/10]  1040) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]  1060) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.912, Accuracy  0.00%
# [ 1/10]  1080) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  1100) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  1120) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.917, Accuracy  0.00%
# [ 1/10]  1140) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.898, Accuracy  0.00%
# [ 1/10]  1160) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]  1180) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  1200) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.901, Accuracy  0.00%
# [ 1/10]  1220) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  1240) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.910, Accuracy  0.00%
# [ 1/10]  1260) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.900, Accuracy  0.00%
# [ 1/10]  1280) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.901, Accuracy  0.00%
# [ 1/10]  1300) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  1320) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.912, Accuracy  0.00%
# [ 1/10]  1340) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.897, Accuracy  0.00%
# [ 1/10]  1360) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  1380) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.899, Accuracy  0.00%
# [ 1/10]  1400) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.900, Accuracy  0.00%
# [ 1/10]  1420) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  1440) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.901, Accuracy  0.00%
# [ 1/10]  1460) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]  1480) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  1500) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.910, Accuracy  0.00%
# [ 1/10]  1520) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  1540) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  1560) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.907, Accuracy  0.00%
# [ 1/10]  1580) [batch load  0.003sec, net 0.05sec], LR 0.00100, Loss:  6.903, Accuracy  0.00%
# [ 1/10]  1600) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.907, Accuracy  0.00%
# [ 1/10]  1620) [batch load  0.003sec, net 0.05sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]  1640) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.900, Accuracy  12.50%
# [ 1/10]  1660) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.916, Accuracy  0.00%
# [ 1/10]  1680) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.907, Accuracy  0.00%
# [ 1/10]  1700) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.902, Accuracy  0.00%
# [ 1/10]  1720) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.899, Accuracy  0.00%
# [ 1/10]  1740) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  1760) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.910, Accuracy  0.00%
# [ 1/10]  1780) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]  1800) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]  1820) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]  1840) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.910, Accuracy  0.00%
# [ 1/10]  1860) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.903, Accuracy  0.00%
# [ 1/10]  1880) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  1900) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.917, Accuracy  0.00%
# [ 1/10]  1920) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.921, Accuracy  0.00%
# [ 1/10]  1940) [batch load  0.004sec, net 0.04sec], LR 0.00100, Loss:  6.901, Accuracy  0.00%
# [ 1/10]  1960) [batch load  0.004sec, net 0.04sec], LR 0.00100, Loss:  6.910, Accuracy  0.00%
# [ 1/10]  1980) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  2000) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]  2020) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]  2040) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]  2060) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  2080) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6
[batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.919, Accuracy  0.00%
# [ 1/10]  4480) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]  4500) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.901, Accuracy  0.00%
# [ 1/10]  4520) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.922, Accuracy  0.00%
# [ 1/10]  4540) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.909, Accuracy  0.00%
# [ 1/10]  4560) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]  4580) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.899, Accuracy  0.00%
# [ 1/10]  4600) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.920, Accuracy  0.00%
# [ 1/10]  4620) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.908, Accuracy  0.00%
# [ 1/10]  4640) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  4660) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  4680) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  4700) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]  4720) [batch load  0.004sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  4740) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  4760) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.917, Accuracy  0.00%
# [ 1/10]  4780) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]  4800) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.925, Accuracy  0.00%
# [ 1/10]  4820) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.901, Accuracy  0.00%
# [ 1/10]  4840) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.913, Accuracy  0.00%
# [ 1/10]  4860) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.920, Accuracy  0.00%
# [ 1/10]  4880) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.924, Accuracy  0.00%
# [ 1/10]  4900) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  4920) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.919, Accuracy  0.00%
# [ 1/10]  4940) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]  4960) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  4980) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  5000) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.921, Accuracy  0.00%
# [ 1/10]  5020) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  5040) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.903, Accuracy  0.00%
# [ 1/10]  5060) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.906, Accuracy  0.00%
# [ 1/10]  5080) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.905, Accuracy  0.00%
# [ 1/10]  5100) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.916, Accuracy  0.00%
# [ 1/10]  5120) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.893, Accuracy  0.00%
# [ 1/10]  5140) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.921, Accuracy  0.00%
# [ 1/10]  5160) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.910, Accuracy  0.00%
# [ 1/10]  5180) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.904, Accuracy  0.00%
# [ 1/10]  5200) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.903, Accuracy  0.00%
# [ 1/10]  5220) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.926, Accuracy  0.00%
# [ 1/10]  5240) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.897, Accuracy  0.00%
# [ 1/10]  5260) [batch load  0.003sec, net 0.03sec], LR 0.00100, Loss:  6.896, Accuracy  0.00%
# [ 1/10]  5280) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.925, Accuracy  0.00%
# [ 1/10]  5300) [batch load  0.003sec, net 0.04sec], LR 0.00100, Loss:  6.928, Accuracy  0.00%
# [ 1/10]  5320) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.911, Accuracy  0.00%
# [ 1/10]  5340) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.917, Accuracy  0.00%
# [ 1/10]  5360) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.924, Accuracy  0.00%
# [ 1/10]  5380) [batch load  0.001sec, net 0.04sec], LR 0.00100, Loss:  6.917, Accuracy  0.00%
# [ 1/10]  5400) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.914, Accuracy  0.00%
# [ 1/10]  5420) [batch load  0.002sec, net 0.04sec], LR 0.00100, Loss:  6.891, Accuracy  0.00%
# [ 1/10]  5440) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.924, Accuracy  0.00%
# [ 1/10]  5460) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.888, Accuracy  0.00%
# [ 1/10]  5480) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
# [ 1/10]  5500) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.893, Accuracy  0.00%
# [ 1/10]  5520) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.886, Accuracy  0.00%
# [ 1/10]  5540) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.899, Accuracy  0.00%
# [ 1/10]  5560) [batch load  0.002sec, net 0.03sec], LR 0.00100, Loss:  6.915, Accuracy  0.00%
